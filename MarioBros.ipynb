# %% [markdown]
# ### 1. Setup Mario

# %%
# https://pypi.org/project/gym-super-mario-bros/
pip install gym_super_mario_bros==7.3.0 nes_py

# %%
# import game
import gym_super_mario_bros
# import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# SIMPLE_MOVEMENT

# setup the game
env =gym_super_mario_bros.make('SuperMarioBros-v0')
env=JoypadSpace(env,SIMPLE_MOVEMENT)
# env.observation_space.shape
# env.action_space
# SIMPLE_MOVEMENT
mov_code=env.action_space.sample()
SIMPLE_MOVEMENT[mov_code]
# Out:
# d:\Project\AI\venv\Lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# ['right', 'A']

# %%
done=True
for step in range(100000):
    if done:
        env.reset()
    env.action_space.sample()
    state, reward, done, info=env.step(env.action_space.sample())
    env.render()
env.close()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 4
#       2 for step in range(100000):
#       3     if done:
# ----> 4         env.reset()
#       5     env.action_space.sample()
#       6     state, reward, done, info=env.step(env.action_space.sample())
#
# File d:\Project\AI\venv\Lib\site-packages\nes_py\wrappers\joypad_space.py:78, in JoypadSpace.reset(self)
#      76 def reset(self):
#      77     """Reset the environment and return the initial observation."""
# ---> 78     return self.env.reset()
#
# File d:\Project\AI\venv\Lib\site-packages\gym\wrappers\time_limit.py:68, in TimeLimit.reset(self, **kwargs)
#      59 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#      60
#      61 Args:
#    (...)
#      65     The reset environment
#      66 """
#      67 self._elapsed_steps = 0
# ---> 68 return self.env.reset(**kwargs)
#
# File d:\Project\AI\venv\Lib\site-packages\gym\wrappers\order_enforcing.py:42, in OrderEnforcing.reset(self, **kwargs)
#      40 """Resets the environment with `kwargs`."""
#      41 self._has_reset = True
# ---> 42 return self.env.reset(**kwargs)
#
# File d:\Project\AI\venv\Lib\site-packages\gym\wrappers\env_checker.py:47, in PassiveEnvChecker.reset(self, **kwargs)
#      45     return env_reset_passive_checker(self.env, **kwargs)
#      46 else:
# ---> 47     return self.env.reset(**kwargs)
#
# File d:\Project\AI\venv\Lib\site-packages\nes_py\nes_env.py:265, in NESEnv.reset(self, seed, options, return_info)
#     263 # reset the emulator
#     264 if self._has_backup:
# --> 265     self._restore()
#     266 else:
#     267     _LIB.Reset(self._env)
#
# File d:\Project\AI\venv\Lib\site-packages\nes_py\nes_env.py:220, in NESEnv._restore(self)
#     218 def _restore(self):
#     219     """Restore the backup state into the NES emulator."""
# --> 220     _LIB.Restore(self._env)
#
# OSError: exception: access violation reading 0x000000000003C208

# %% [markdown]
# ### 2. Preprocess Enviroment
